# %% [markdown]
# # Week1
# エラー処理

# %%
x = 1
y = 0

# %%
try:
    result = x/y
except ZeroDivisionError as e:
    print(f"エラー発生した error:{e}")
# Out:
# エラー発生した error:division by zero

# %% [markdown]
# ## 複数のエラーの場合

# %%
try:
    result = x/a
except ZeroDivisionError as e:
    print(f"エラー発生した error:{e}")
except NameError as e:
    print(f"エラー発生した error:{e}")
# Out:
# エラー発生した error:name 'a' is not defined

# %%
try:
    result = 1/2
except ZeroDivisionError as e:
    print(f"エラー発生した error:{e}")
except NameError as e:
    print(f"エラー発生した error:{e}")
else:
    print("no error")
# Out:
# no error

# %% [markdown]
# ## すべてのエラー

# %%
try:
    result = 1/E
except Exception as e:
    print(f"エラー発生した error:{e}")
print(None)
# Out:
# エラー発生した error:name 'E' is not defined
# None

# %%
import requests

# %%
url = "https://www.musashino-u.ac.jp/xxxx"

try:
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(f"error: {e}")
# Out:
# error: 404 Client Error: Not Found for url: https://www.musashino-u.ac.jp/xxxx
